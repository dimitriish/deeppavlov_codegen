# %%
import pandas as pd

# %%
pd.read_csv('only_nl_t5_code.csv').T
# Out:
#                                            0        1        2
# Random                               0.15225  0.46492  0.78458
# Jaccard                              0.15317  0.45708  0.77808
# ES                                   0.15525  0.46175  0.78075
# BM25                                 0.15158  0.45767  0.77483
# Unixcoder                            0.15492  0.46175  0.78092
# all-MiniLM-L6-v2                     0.14850  0.46158  0.78325
# all-mpnet-base-v2                    0.14758  0.47250  0.78492
# multi-qa-mpnet-base-dot-v1           0.14758  0.47250  0.78492
# all-distilroberta-v1                 0.15100  0.46342  0.78142
# all-MiniLM-L12-v2                    0.14825  0.46583  0.78150
# multi-qa-distilbert-cos-v1           0.15333  0.46642  0.78592
# multi-qa-MiniLM-L6-cos-v1            0.15008  0.46408  0.78425
# all-roberta-large-v1                 0.14667  0.45850  0.78092
# msmarco-MiniLM-L-6-v3                0.15267  0.46358  0.78075
# ...

# %%
pd.read_csv('with_nl_t5_code.csv').T
# Out:
#                                            0        1        2
# Random                               0.15250  0.47042  0.78158
# Jaccard                              0.17925  0.50208  0.80375
# ES                                   0.16092  0.47900  0.78950
# BM25                                 0.20375  0.53550  0.81317
# Unixcoder                            0.23183  0.57242  0.83717
# all-MiniLM-L6-v2                     0.23550  0.57217  0.84150
# all-mpnet-base-v2                    0.22633  0.56508  0.84133
# msmarco-MiniLM-L-6-v3                0.20308  0.54342  0.82308
# msmarco-MiniLM-L-12-v3               0.20867  0.54733  0.82467
# msmarco-distilbert-base-v3           0.21792  0.55250  0.83042
# msmarco-distilbert-base-v4           0.21158  0.53708  0.82358
# msmarco-roberta-base-v3              0.20008  0.54017  0.82175
# msmarco-distilbert-base-dot-prod-v3  0.19983  0.53658  0.81958
# msmarco-roberta-base-ance-firstp     0.20275  0.53567  0.81825
# ...

# %%
pd.read_csv('without_nl_t5_code.csv').T
# Out:
#                                            0        1        2
# Random                               0.15008  0.46842  0.78217
# Jaccard                              0.18833  0.50867  0.80508
# ES                                   0.16150  0.47792  0.78933
# BM25                                 0.21717  0.54400  0.81158
# Unixcoder                            0.26117  0.59967  0.85017
# all-MiniLM-L6-v2                     0.26600  0.60842  0.85742
# all-mpnet-base-v2                    0.26908  0.61683  0.85750
# msmarco-MiniLM-L-6-v3                0.23833  0.58075  0.83675
# msmarco-MiniLM-L-12-v3               0.24117  0.57975  0.84000
# msmarco-distilbert-base-v3           0.24975  0.58167  0.84858
# msmarco-distilbert-base-v4           0.24142  0.57808  0.84075
# msmarco-roberta-base-v3              0.24983  0.59083  0.84858
# msmarco-distilbert-base-dot-prod-v3  0.23183  0.56950  0.83783
# msmarco-roberta-base-ance-firstp     0.24875  0.58317  0.84217
# ...

# %%
df.to_csv(res, index=False)

# %%
pd.read_csv('../symmetric/without_nl_t5_code.csv').T
# Out:
#                                   0        1        2
# Unnamed: 0.1                0.00000  1.00000  2.00000
# Unnamed: 0                  0.00000  1.00000  2.00000
# Random                      0.15508  0.47033  0.78442
# Jaccard                     0.39392  0.67875  0.88208
# ES                          0.39392  0.67875  0.88208
# BM25                        0.63067  0.88967  0.96183
# Unixcoder                   0.65483  0.88983  0.97050
# all-MiniLM-L6-v2            0.74958  0.93875  0.98217
# all-mpnet-base-v2           0.77542  0.94458  0.98425
# multi-qa-mpnet-base-dot-v1  0.77542  0.94458  0.98425
# all-distilroberta-v1        0.76933  0.94383  0.98433
# all-MiniLM-L12-v2           0.81292  0.95100  0.98517
# multi-qa-distilbert-cos-v1  0.76700  0.94450  0.98317
# multi-qa-MiniLM-L6-cos-v1   0.74642  0.93875  0.98167
# all-roberta-large-v1        0.78233  0.94700  0.98425
# e5-large                    0.68717  0.92475  0.98192
# ...
